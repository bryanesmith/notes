# %% [markdown]
# We're going to finetune GPT-2 to classify emotions in text. Before that, we'll create and score a baseline emotion classifier.

# %%
from datetime import datetime, timedelta
import gzip
import json
import random
import re
import requests
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import torch
from torch.optim import AdamW 
from torch.utils.data import Dataset, DataLoader
from transformers import AutoTokenizer, AutoModelForCausalLM
from tqdm import tqdm

# %%
random_state = 42
random.seed(random_state)

# %% [markdown]
# ## Utilities

# %%
# Source: https://github.com/bryanesmith/notes/blob/master/The%20Hundred-Page%20Language%20Models%20Book/Chap%203/RNN.ipynb
def get_device_label():
    if torch.backends.mps.is_available():
        return "mps"
    elif torch.cuda.is_available():
        return "cuda"
    else:
        return "cpu"


# Source: https://github.com/bryanesmith/notes/blob/master/The%20Hundred-Page%20Language%20Models%20Book/Chap%204/decoder-only-transformer.ipynb
def print_training_progress(batch_idx, start, train_dataloader, epoch):
    ellapsed = datetime.now() - start
    percent_done = 100 * batch_idx/len(train_dataloader)
    estimated_total_time = 'unknown'
    if percent_done > 0:
        estimated_total_time = f'{ellapsed.total_seconds() / (percent_done/100) / (60 * 60):.1f} hr'
    print(f'[epoch={epoch}] batch {batch_idx} of {len(train_dataloader)} - {percent_done:.2f}% done - {timedelta(seconds=ellapsed.total_seconds())} ellapsed, est. total time: {estimated_total_time}')



# Source: https://github.com/aburkov/theLMbook/blob/main/emotion_classifier_LR.ipynb
def download_and_split_data(data_url, test_ratio=0.1):
    """
    Downloads emotion classification dataset from URL and splits into train/test sets.
    Handles decompression and JSON parsing of the raw data.

    Args:
        data_url (str): URL of the gzipped JSON dataset
        test_ratio (float): Proportion of data to use for testing (default: 0.1)

    Returns:
        tuple: (X_train, y_train, X_test, y_test) containing:
            - X_train, X_test: Lists of text examples for training and testing
            - y_train, y_test: Lists of corresponding emotion labels
    """
    # Download and decompress the dataset
    response = requests.get(data_url)
    content = gzip.decompress(response.content).decode()

    # Parse JSON lines into list of dictionaries
    dataset = [json.loads(line) for line in content.splitlines()]

    # Shuffle dataset for random split
    random.shuffle(dataset)

    # Split into train and test sets
    split_index = int(len(dataset) * (1 - test_ratio))
    train, test = dataset[:split_index], dataset[split_index:]

    # Separate text and labels
    X_train = [item["text"] for item in train]
    y_train = [item["label"] for item in train]
    X_test = [item["text"] for item in test]
    y_test = [item["label"] for item in test]

    return X_train, y_train, X_test, y_test


# Source: https://github.com/aburkov/theLMbook/blob/main/emotion_GPT2_as_text_generator.ipynb
def download_and_prepare_data(data_url, tokenizer, batch_size, test_ratio=0.1):
    """
    Downloads and prepares dataset for training.

    Args:
        data_url (str): URL of the dataset
        tokenizer: Tokenizer for text processing
        batch_size (int): Batch size for DataLoader
        test_ratio (float): Proportion of data for testing

    Returns:
        tuple: (train_loader, test_loader)
    """
    # Download compressed dataset
    response = requests.get(data_url)
    # Decompress and decode the content
    content = gzip.decompress(response.content).decode()

    # Parse each line as JSON and format into prompt-completion pairs
    dataset = []
    for entry in map(json.loads, content.splitlines()):
        dataset.append({
            "prompt": build_prompt(entry['text']),
            "completion": entry["label"].strip()
        })

    # Randomly shuffle dataset for better split
    random.shuffle(dataset)
    # Calculate split index based on test ratio
    split_index = int(len(dataset) * (1 - test_ratio))
    # Split into train and test sets
    train_data = dataset[:split_index]
    test_data = dataset[split_index:]

    # Create dataset objects
    train_dataset = PromptCompletionDataset(train_data, tokenizer)
    test_dataset = PromptCompletionDataset(test_data, tokenizer)

    # Create data loaders with appropriate settings
    train_loader = DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,         # Shuffle training data
        collate_fn=collate_fn  # Custom collation for padding
    )
    test_loader = DataLoader(
        test_dataset,
        batch_size=batch_size,
        shuffle=False,        # Don't shuffle test data
        collate_fn=collate_fn
    )

    return train_loader, test_loader


# Source: https://github.com/aburkov/theLMbook/blob/main/emotion_GPT2_as_text_generator.ipynb
def build_prompt(text):
    """
    Creates a standardized prompt for emotion classification.

    Args:
        text (str): Input text to classify

    Returns:
        str: Formatted prompt for the model
    """
    # Format the input text into a consistent prompt structure
    # Include explicit task instruction and expected output format
    return f"Predict the emotion for the following text: {text}\nEmotion:"


# Source: https://github.com/aburkov/theLMbook/blob/main/emotion_GPT2_as_text_generator.ipynb
class PromptCompletionDataset(Dataset):
    """
    PyTorch Dataset for prompt-completion pairs.
    Handles the conversion of text data into model-ready format.

    Args:
        data (list): List of dictionaries containing prompts and completions
        tokenizer: Hugging Face tokenizer
    """
    def __init__(self, data, tokenizer):
        # Store the raw data and tokenizer for later use
        self.data = data
        self.tokenizer = tokenizer

    def __len__(self):
        # Return the total number of examples in the dataset
        return len(self.data)

    def __getitem__(self, idx):
        """
        Returns a single training example.

        Args:
            idx (int): Index of the example to fetch

        Returns:
            dict: Contains input_ids, labels, prompt, and expected completion
        """
        # Get the specific example from our dataset
        item = self.data[idx]
        prompt = item["prompt"]
        completion = item["completion"]

        # Convert text to token IDs for both prompt and completion
        encoded_prompt = encode_text(self.tokenizer, prompt)
        encoded_completion = encode_text(self.tokenizer, completion)
        # Get the end-of-sequence token ID
        eos_token = self.tokenizer.eos_token_id

        # Combine prompt and completion tokens with EOS token
        input_ids = encoded_prompt + encoded_completion + [eos_token]
        # Create labels: -100 for prompt (ignored in loss), completion tokens for learning
        labels = [-100] * len(encoded_prompt) + encoded_completion + [eos_token]

        return {
            "input_ids": input_ids,
            "labels": labels,
            "prompt": prompt,
            "expected_completion": completion
        }


# Source: https://github.com/aburkov/theLMbook/blob/main/emotion_GPT2_as_text_generator.ipynb
def collate_fn(batch):
    """
    Collates batch of examples into training-ready format.
    Handles padding and conversion to tensors.

    Args:
        batch: List of examples from Dataset

    Returns:
        tuple: (input_ids, attention_mask, labels, prompts, expected_completions)
    """
    # Find the longest sequence in the batch for padding
    max_length = max(len(item["input_ids"]) for item in batch)

    # Pad input sequences to max_length with pad token
    input_ids = [
        item["input_ids"] +
        [tokenizer.pad_token_id] * (max_length - len(item["input_ids"]))
        for item in batch
    ]

    # Pad label sequences with -100 (ignored in loss calculation)
    labels = [
        item["labels"] +
        [-100] * (max_length - len(item["labels"]))
        for item in batch
    ]

    # Create attention masks: 1 for real tokens, 0 for padding
    attention_mask = [
        [1] * len(item["input_ids"]) +
        [0] * (max_length - len(item["input_ids"]))
        for item in batch
    ]

    # Keep original prompts and completions for evaluation
    prompts = [item["prompt"] for item in batch]
    expected_completions = [item["expected_completion"] for item in batch]

    # Convert everything to PyTorch tensors except text
    return (
        torch.tensor(input_ids),
        torch.tensor(attention_mask),
        torch.tensor(labels),
        prompts,
        expected_completions
    )


# Source: https://github.com/aburkov/theLMbook/blob/main/emotion_GPT2_as_text_generator.ipynb
def encode_text(tokenizer, text, return_tensor=False):
    """
    Encodes text using the provided tokenizer.

    Args:
        tokenizer: Hugging Face tokenizer
        text (str): Text to encode
        return_tensor (bool): Whether to return PyTorch tensor

    Returns:
        List or tensor of token IDs
    """
    # If tensor output is requested, encode with PyTorch tensors
    if return_tensor:
        return tokenizer.encode(
            text, add_special_tokens=False, return_tensors="pt"
        )
    # Otherwise return list of token IDs
    else:
        return tokenizer.encode(text, add_special_tokens=False)


# Source: https://github.com/aburkov/theLMbook/blob/main/emotion_GPT2_as_text_generator.ipynb
def decode_text(tokenizer, token_ids):
    """
    Decodes token IDs back to text.

    Args:
        tokenizer: Hugging Face tokenizer
        token_ids: List or tensor of token IDs

    Returns:
        str: Decoded text
    """
    # Convert token IDs back to text, skipping special tokens
    return tokenizer.decode(token_ids, skip_special_tokens=True)


# Source: https://github.com/aburkov/theLMbook/blob/main/emotion_GPT2_as_text_generator.ipynb
def calculate_accuracy(model, tokenizer, loader):
    """
    Calculates prediction accuracy on a dataset.

    Args:
        model: Fine-tuned model
        tokenizer: Associated tokenizer
        loader: DataLoader containing evaluation examples

    Returns:
        float: Accuracy score
    """
    # Initialize counters for accuracy calculation
    correct = 0
    total = 0

    # Disable gradient computation for efficiency
    with torch.no_grad():
        # Iterate through batches
        for input_ids, attention_mask, labels, prompts, expected_completions in loader:
            # Process each example in the batch
            for prompt, expected_completion in zip(prompts, expected_completions):
                # Generate model's prediction for this prompt
                generated_text = generate_text(model, tokenizer, prompt)
                # Compare normalized versions of prediction and expected completion
                if normalize_text(generated_text) == normalize_text(expected_completion):
                    correct += 1
                total += 1

    # Calculate accuracy, handling empty dataset case
    accuracy = correct / total if total > 0 else 0
    # Reset model to training mode
    return accuracy


# Source: https://github.com/aburkov/theLMbook/blob/main/emotion_GPT2_as_text_generator.ipynb
def generate_text(model, tokenizer, prompt, max_new_tokens=50):
    """
    Generates text completion for a given prompt.

    Args:
        model: Fine-tuned model
        tokenizer: Associated tokenizer
        prompt (str): Input prompt
        max_new_tokens (int): Maximum number of tokens to generate

    Returns:
        str: Generated completion
    """
    # Encode prompt and move to model's device
    input_ids = tokenizer(prompt, return_tensors="pt").to(model.device)

    # Generate completion using model
    output_ids = model.generate(
        input_ids=input_ids["input_ids"],
        attention_mask=input_ids["attention_mask"],
        max_new_tokens=max_new_tokens,
        pad_token_id=tokenizer.pad_token_id,
        eos_token_id=tokenizer.eos_token_id,
        use_cache=True,        # Use KV cache for faster generation
        num_beams=1,           # Use greedy decoding
        do_sample=False,       # Don't use sampling
    )[0]

    # Extract and decode only the generated part (excluding prompt)
    generated_text = decode_text(tokenizer, output_ids[input_ids["input_ids"].shape[1]:])
    return generated_text.strip()


# Source: https://github.com/aburkov/theLMbook/blob/main/emotion_GPT2_as_text_generator.ipynb
def normalize_text(text):
    """
    Normalizes text for consistent comparison.

    Args:
        text (str): Input text

    Returns:
        str: Normalized text
    """
    # Remove leading/trailing whitespace and convert to lowercase
    text = text.strip().lower()
    # Replace multiple whitespace characters with single space
    text = re.sub(r'\s+', ' ', text)
    return text

# %% [markdown]
# ## Baseline Emotion Classifier
#
# We'll use a multinomial logistic regression as a baseline model, with expectation that if we finetune our LLM properly, it should outperform the logistic regression.
#
# ### Dataset
# We'll download a JSONL dataset with the following format:
#
# ```
# {"text": "i slammed the door and yelled", "label": "anger"}
# ```
#
# We will split this labeled data into training and test datasets. We then transform the data into a **bag-of-words**.

# %%
data_url = "https://www.thelmbook.com/data/emotions"
X_train_text, y_train, X_test_text, y_test = download_and_split_data(data_url, test_ratio=0.1)
print(f'|X_train_text| = {len(X_train_text)} ; |X_test_text| = {len(X_test_text)}')
# Out:
# |X_train_text| = 18000 ; |X_test_text| = 2000

# %%
vectorizer = CountVectorizer(max_features=10_000, binary=True)
X_train = vectorizer.fit_transform(X_train_text)
X_test = vectorizer.transform(X_test_text)

print(f'|X_train| = {X_train.shape} ; |X_test| = {X_test.shape}')
# Out:
# |X_train| = (18000, 10000) ; |X_test| = (2000, 10000)

# %% [markdown]
# ### Build & Train
#
# Next we train and test the model. We'll use accuracy as our metric for comparison.

# %%
model = LogisticRegression(random_state=random_state, max_iter=1000)
model.fit(X_train, y_train)

y_train_pred = model.predict(X_train)

train_accuracy = accuracy_score(y_train, y_train_pred)

print(f'Training accuracy: {train_accuracy * 100:.2f}%')
# Out:
# Training accuracy: 98.43%

# %% [markdown]
# ### Evaluate

# %%
y_test_pred = model.predict(X_test)
test_accuracy = accuracy_score(y_test, y_test_pred)
print(f'Test accuracy: {test_accuracy * 100:.2f}%')
# Out:
# Test accuracy: 90.10%

# %% [markdown]
# ## Finetuning GPT-2

# %%
device = get_device_label()
device = "cpu" # workaround "MPS backend out of memory"

# %% [markdown]
# ### Dataset

# %%
model_name = "openai-community/gpt2"
num_epochs=8
batch_size=16
learning_rate=5e-5 # standard tuning rate for finetuning transformers

tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

# %%
train_loader, test_loader = download_and_prepare_data(
    data_url, tokenizer, batch_size
)

print(f'|train_loader| = {len(train_loader)} ; |test_loader| = {len(test_loader)}')
# Out:
# |train_loader| = 1125 ; |test_loader| = 125

# %% [markdown]
# ### Build & Train

# %%
model = AutoModelForCausalLM.from_pretrained(model_name).to(device)
optimizer = AdamW(model.parameters(), lr=learning_rate)
start = datetime.now()
update_batch_cnt = len(train_loader) // 200  # print an update every 0.5% of progress

for epoch in range(num_epochs):
    for batch_idx, (input_ids, attention_mask, labels, _, _) in enumerate(train_loader):
        if batch_idx % update_batch_cnt == 0:
            print_training_progress(batch_idx, start, train_loader, epoch)
        input_ids = input_ids.to(device)
        attention_mask = attention_mask.to(device)
        labels = labels.to(device)
        outputs = model(input_ids=input_ids, labels=labels, attention_mask=attention_mask)
        outputs.loss.backward()
        optimizer.step()
        optimizer.zero_grad()
# Out:
# [epoch=0] batch 0 of 1125 - 0.00% done - 0:00:00.042153 ellapsed, est. total time: unknown
# [epoch=0] batch 5 of 1125 - 0.44% done - 0:00:08.362048 ellapsed, est. total time: 0.5 hr
# [epoch=0] batch 10 of 1125 - 0.89% done - 0:00:16.059798 ellapsed, est. total time: 0.5 hr
# [epoch=0] batch 15 of 1125 - 1.33% done - 0:00:24.980465 ellapsed, est. total time: 0.5 hr
# [epoch=0] batch 20 of 1125 - 1.78% done - 0:00:32.024190 ellapsed, est. total time: 0.5 hr
# [epoch=0] batch 25 of 1125 - 2.22% done - 0:00:39.219023 ellapsed, est. total time: 0.5 hr
# [epoch=0] batch 30 of 1125 - 2.67% done - 0:00:46.671640 ellapsed, est. total time: 0.5 hr
# [epoch=0] batch 35 of 1125 - 3.11% done - 0:00:53.991504 ellapsed, est. total time: 0.5 hr
# [epoch=0] batch 40 of 1125 - 3.56% done - 0:01:00.917847 ellapsed, est. total time: 0.5 hr
# [epoch=0] batch 45 of 1125 - 4.00% done - 0:01:09.041752 ellapsed, est. total time: 0.5 hr
# [epoch=0] batch 50 of 1125 - 4.44% done - 0:01:16.398622 ellapsed, est. total time: 0.5 hr
# [epoch=0] batch 55 of 1125 - 4.89% done - 0:01:25.958829 ellapsed, est. total time: 0.5 hr
# [epoch=0] batch 60 of 1125 - 5.33% done - 0:01:33.025389 ellapsed, est. total time: 0.5 hr
# [epoch=0] batch 65 of 1125 - 5.78% done - 0:01:39.862201 ellapsed, est. total time: 0.5 hr
# [epoch=0] batch 70 of 1125 - 6.22% done - 0:01:48.069200 ellapsed, est. total time: 0.5 hr
# [epoch=0] batch
# [epoch=1] batch 50 of 1125 - 4.44% done - 0:29:41.186472 ellapsed, est. total time: 11.1 hr
# [epoch=1] batch 55 of 1125 - 4.89% done - 0:29:48.515075 ellapsed, est. total time: 10.2 hr
# [epoch=1] batch 60 of 1125 - 5.33% done - 0:29:55.637515 ellapsed, est. total time: 9.4 hr
# [epoch=1] batch 65 of 1125 - 5.78% done - 0:30:03.324166 ellapsed, est. total time: 8.7 hr
# [epoch=1] batch 70 of 1125 - 6.22% done - 0:30:10.634660 ellapsed, est. total time: 8.1 hr
# [epoch=1] batch 75 of 1125 - 6.67% done - 0:30:17.663185 ellapsed, est. total time: 7.6 hr
# [epoch=1] batch 80 of 1125 - 7.11% done - 0:30:25.009066 ellapsed, est. total time: 7.1 hr
# [epoch=1] batch 85 of 1125 - 7.56% done - 0:30:32.323773 ellapsed, est. total time: 6.7 hr
# [epoch=1] batch 90 of 1125 - 8.00% done - 0:30:39.761432 ellapsed, est. total time: 6.4 hr
# [epoch=1] batch 95 of 1125 - 8.44% done - 0:30:46.494709 ellapsed, est. total time: 6.1 hr
# [epoch=1] batch 100 of 1125 - 8.89% done - 0:30:53.777001 ellapsed, est. total time: 5.8 hr
# [epoch=1] batch 105 of 1125 - 9.33% done - 0:31:00.795376 ellapsed, est. total time: 5.5 hr
# [epoch=1] batch 110 of 1125 - 9.78% done - 0:31:08.119425 ellapsed, est. total time: 5.3 hr
# [epoch=1] batch 115 of 1125 - 10.22% done - 0:31:15.998067 ellapsed, est. total time: 5.1 hr
# [epoch=1] batch 120 of 1125 - 10.67% done - 0:31:24.320141 ellapsed, est. total time: 4.9 hr
# [epoch=1] batch 125 of 1125 - 11.11% done - 0:31:32.542247 ellapsed, est. total time: 4.7 hr
# [epoch=1] batch 130 of 1125 - 11.56% done - 0:31:39.721997 ellapsed, est. total time: 4.6 hr
# [epoch=1] batch 135 of 1125 - 12.00% done - 0:31:47.869740 ellapsed, est. total time: 4.4 hr
# [epoch=1] batch 140 of 1125 - 12.44% done - 0:31:55.045178 ellapsed, est. total time: 4.3 hr
# [epoch=1] batch 145 of 1125 - 12.89% done - 0:32:02.654780 ellapsed, est. total time: 4.1 hr
# [epoch=1] batch 150 of 1125 - 13.33% done - 0:32:10.911675 ellapsed, est. total time: 4.0 hr
# [epoch=1] batch 155 of 1125 - 13.78% done - 0:32:18.227865 ellapsed, est. total time: 3.9 hr
# [epoch=1] batch 160 of 1125 - 14.22% done - 0:32:25.618708 ellapsed, est. total time: 3.8 hr
# [epoch=1] batch 165 of 1125 - 14.67% done - 0:32:33.172309 ellapsed, est. total time: 3.7 hr
# [epoch=1] batch 170 of 1125 - 15.11% done - 0:32:40.822972 ellapsed, est. total time: 3.6 hr
# [epoch=1] batch 175 of 1125 - 15.56% done - 0:32:48.008055 ellapsed, est. total time: 3.5 hr
# [epoch=1] batch 180 of 1125 - 16.00% done - 0:32:56.459747 ellapsed, est. total time: 3.4 hr
# [epoch=1] batch 185 of 1125 - 16.44% done - 0:33:03.453243 ellapsed, est. total time: 3.4 hr
# [epoch=1] batch 190 of 1125 - 16.89% done - 0:33:10.516112 ellapsed, est. total time: 3.3 hr
# [epoch=1] batch 195 of 1125 - 17.33% done - 0:33:17.953472 ellapsed, est. total time: 3.2 hr
# [epoch=1] batch 200 of 1125 - 17.78% done - 0:33:26.166893 ellapsed, est. total time: 3.1 hr
# [epoch=1] batch 205 of 1125 - 18.22% done - 0:33:32.859662 ellapsed, est. total time: 3.1 hr
# [epoch=1] batch 210 of 1125 - 18.67% done - 0:33:40.212405 ellapsed, est. total time: 3.0 hr
# [epoch=1] batch 215 of 1125 - 19.11% done - 0:33:48.539042 ellapsed, est. total time: 2.9 hr
# [epoch=1] batch 220 of 1125 - 19.56% done - 0:33:56.838673 ellapsed, est. total time: 2.9 hr
# [epoch=1] batch 225 of 1125 - 20.00% done - 0:34:03.656439 ellapsed, est. total time: 2.8 hr
# [epoch=1] batch 230 of 1125 - 20.44% done - 0:34:11.562184 ellapsed, est. total time: 2.8 hr
# [epoch=1] batch 235 of 1125 - 20.89% done - 0:34:19.637852 ellapsed, est. total time: 2.7 hr
# [epoch=1] batch 240 of 1125 - 21.33% done - 0:34:26.394448 ellapsed, est. total time: 2.7 hr
# [epoch=1] batch 245 of 1125 - 21.78% done - 0:34:34.013144 ellapsed, est. total time: 2.6 hr
# [epoch=1] batch 250 of 1125 - 22.22% done - 0:34:41.771318 ellapsed, est. total time: 2.6 hr
# [epoch=1] batch 255 of 1125 - 22.67% done - 0:34:49.386800 ellapsed, est. total time: 2.6 hr
# [epoch=1] batch 260 of 1125 - 23.11% done - 0:34:56.418204 ellapsed, est. total time: 2.5 hr
# [epoch=1] batch 265 of 1125 - 23.56% done - 0:35:03.279386 ellapsed, est. total time: 2.5 hr
# [epoch=1] batch 270 of 1125 - 24.00% done - 0:35:10.919337 ellapsed, est. total time: 2.4 hr
# [epoch=1] batch 275 of 1125 - 24.44% done - 0:35:17.891576 ellapsed, est. total time: 2.4 hr
# [epoch=1] batch 280 of 1125 - 24.89% done - 0:35:25.147565 ellapsed, est. total time: 2.4 hr
# [epoch=1] batch 285 of 1125 - 25.33% done - 0:35:32.097910 ellapsed, est. total time: 2.3 hr
# [epoch=1] batch 290 of 1125 - 25.78% done - 0:35:40.224839 ellapsed, est. total time: 2.3 hr
# [epoch=1] batch 295 of 1125 - 26.22% done - 0:35:47.834439 ellapsed, est. total time: 2.3 hr
# [epoch=1] batch 300 of 1125 - 26.67% done - 0:35:54.008580 ellapsed, est. total time: 2.2 hr
# [epoch=1] batch 305 of 1125 - 27.11% done - 0:36:00.797385 ellapsed, est. total time: 2.2 hr
# [epoch=1] batch 310 of 1125 - 27.56% done - 0:36:08.105548 ellapsed, est. total time: 2.2 hr
# [epoch=1] batch 315 of 1125 - 28.00% done - 0:36:15.300287 ellapsed, est. total time: 2.2 hr
# [epoch=1] batch 320 of 1125 - 28.44% done - 0:36:22.798822 ellapsed, est. total time: 2.1 hr
# [epoch=1] batch 325 of 1125 - 28.89% done - 0:36:30.383526 ellapsed, est. total time: 2.1 hr
# [epoch=1] batch 330 of 1125 - 29.33% done - 0:36:37.953888 ellapsed, est. total time: 2.1 hr
# [epoch=1] batch 335 of 1125 - 29.78% done - 0:36:45.039505 ellapsed, est. total time: 2.1 hr
# [epoch=1] batch 340 of 1125 - 30.22% done - 0:36:51.751741 ellapsed, est. total time: 2.0 hr
# [epoch=1] batch 345 of 1125 - 30.67% done - 0:36:59.140383 ellapsed, est. total time: 2.0 hr
# [epoch=1] batch 350 of 1125 - 31.11% done - 0:37:06.856760 ellapsed, est. total time: 2.0 hr
# [epoch=1] batch 355 of 1125 - 31.56% done - 0:37:14.542663 ellapsed, est. total time: 2.0 hr
# [epoch=1] batch 360 of 1125 - 32.00% done - 0:37:21.033980 ellapsed, est. total time: 1.9 hr
# [epoch=1] batch 365 of 1125 - 32.44% done - 0:37:28.336115 ellapsed, est. total time: 1.9 hr
# [epoch=1] batch 370 of 1125 - 32.89% done - 0:37:35.053322 ellapsed, est. total time: 1.9 hr
# [epoch=1] batch 375 of 1125 - 33.33% done - 0:37:42.705679 ellapsed, est. total time: 1.9 hr
# [epoch=1] batch 380 of 1125 - 33.78% done - 0:37:49.290986 ellapsed, est. total time: 1.9 hr
# [epoch=1] batch 385 of 1125 - 34.22% done - 0:38:00.553436 ellapsed, est. total time: 1.9 hr
# [epoch=1] batch 390 of 1125 - 34.67% done - 0:38:08.503279 ellapsed, est. total time: 1.8 hr
# [epoch=1] batch 395 of 1125 - 35.11% done - 0:38:16.615087 ellapsed, est. total time: 1.8 hr
# [epoch=1] batch 400 of 1125 - 35.56% done - 0:38:23.275563 ellapsed, est. total time: 1.8 hr
# [epoch=1] batch 405 of 1125 - 36.00% done - 0:38:30.771568 ellapsed, est. total time: 1.8 hr
# [epoch=1] batch 410 of 1125 - 36.44% done - 0:38:37.486640 ellapsed, est. total time: 1.8 hr
# [epoch=1] batch 415 of 1125 - 36.89% done - 0:38:44.288063 ellapsed, est. total time: 1.8 hr
# [epoch=1] batch 420 of 1125 - 37.33% done - 0:38:51.895879 ellapsed, est. total time: 1.7 hr
# [epoch=1] batch 425 of 1125 - 37.78% done - 0:38:59.877183 ellapsed, est. total time: 1.7 hr
# [epoch=1] batch 430 of 1125 - 38.22% done - 0:39:07.637751 ellapsed, est. total time: 1.7 hr
# [epoch=1] batch 435 of 1125 - 38.67% done - 0:39:15.027174 ellapsed, est. total time: 1.7 hr
# [epoch=1] batch 440 of 1125 - 39.11% done - 0:39:23.770688 ellapsed, est. total time: 1.7 hr
# [epoch=1] batch 445 of 1125 - 39.56% done - 0:39:30.940350 ellapsed, est. total time: 1.7 hr
# [epoch=1] batch 450 of 1125 - 40.00% done - 0:39:38.499218 ellapsed, est. total time: 1.7 hr
# [epoch=1] batch 455 of 1125 - 40.44% done - 0:39:46.408193 ellapsed, est. total time: 1.6 hr
# [epoch=1] batch 460 of 1125 - 40.89% done - 0:39:53.647419 ellapsed, est. total time: 1.6 hr
# [epoch=1] batch 465 of 1125 - 41.33% done - 0:40:01.419562 ellapsed, est. total time: 1.6 hr
# [epoch=1] batch 470 of 1125 - 41.78% done - 0:40:09.729584 ellapsed, est. total time: 1.6 hr
# [epoch=2] batch 75 of 1125 - 6.67% done - 1:00:06.580798 ellapsed, est. total time: 15.0 hr
# [epoch=2] batch 80 of 1125 - 7.11% done - 1:00:14.590353 ellapsed, est. total time: 14.1 hr
# [epoch=2] batch 85 of 1125 - 7.56% done - 1:00:22.341876 ellapsed, est. total time: 13.3 hr
# [epoch=2] batch 90 of 1125 - 8.00% done - 1:00:30.110428 ellapsed, est. total time: 12.6 hr
# [epoch=2] batch 95 of 1125 - 8.44% done - 1:00:39.015790 ellapsed, est. total time: 12.0 hr
# [epoch=2] batch 100 of 1125 - 8.89% done - 1:00:48.923327 ellapsed, est. total time: 11.4 hr
# [epoch=2] batch 105 of 1125 - 9.33% done - 1:00:56.722668 ellapsed, est. total time: 10.9 hr
# [epoch=2] batch 110 of 1125 - 9.78% done - 1:01:04.141303 ellapsed, est. total time: 10.4 hr
# [epoch=2] batch 115 of 1125 - 10.22% done - 1:01:12.058743 ellapsed, est. total time: 10.0 hr
# [epoch=2] batch 120 of 1125 - 10.67% done - 1:01:20.611673 ellapsed, est. total time: 9.6 hr
# [epoch=2] batch 125 of 1125 - 11.11% done - 1:01:28.733846 ellapsed, est. total time: 9.2 hr
# [epoch=2] batch 130 of 1125 - 11.56% done - 1:01:37.931635 ellapsed, est. total time: 8.9 hr
# [epoch=2] batch 135 of 1125 - 12.00% done - 1:01:46.567546 ellapsed, est. total time: 8.6 hr
# [epoch=2] batch 140 of 1125 - 12.44% done - 1:01:55.121646 ellapsed, est. total time: 8.3 hr
# [epoch=2] batch 145 of 1125 - 12.89% done - 1:02:04.823089 ellapsed, est. total time: 8.0 hr
# [epoch=2] batch 150 of 1125 - 13.33% done - 1:02:13.327896 ellapsed, est. total time: 7.8 hr
# [epoch=2] batch 155 of 1125 - 13.78% done - 1:02:23.871855 ellapsed, est. total time: 7.5 hr
# [epoch=2] batch 160 of 1125 - 14.22% done - 1:02:32.569576 ellapsed, est. total time: 7.3 hr
# [epoch=2] batch 165 of 1125 - 14.67% done - 1:02:42.227132 ellapsed, est. total time: 7.1 hr
# [epoch=2] batch 170 of 1125 - 15.11% done - 1:02:52.870937 ellapsed, est. total time: 6.9 hr
# [epoch=2] batch 175 of 1125 - 15.56% done - 1:03:02.238833 ellapsed, est. total time: 6.8 hr
# [epoch=2] batch 180 of 1125 - 16.00% done - 1:03:10.953010 ellapsed, est. total time: 6.6 hr
# [epoch=2] batch 185 of 1125 - 16.44% done - 1:03:20.166860 ellapsed, est. total time: 6.4 hr
# [epoch=2] batch 190 of 1125 - 16.89% done - 1:03:29.078787 ellapsed, est. total time: 6.3 hr
# [epoch=2] batch 195 of 1125 - 17.33% done - 1:03:37.806886 ellapsed, est. total time: 6.1 hr
# [epoch=2] batch 200 of 1125 - 17.78% done - 1:03:46.921087 ellapsed, est. total time: 6.0 hr
# [epoch=2] batch 205 of 1125 - 18.22% done - 1:03:54.633367 ellapsed, est. total time: 5.8 hr
# [epoch=2] batch 210 of 1125 - 18.67% done - 1:04:03.418385 ellapsed, est. total time: 5.7 hr
# [epoch=2] batch 215 of 1125 - 19.11% done - 1:04:11.372707 ellapsed, est. total time: 5.6 hr
# [epoch=2] batch 220 of 1125 - 19.56% done - 1:04:19.544988 ellapsed, est. total time: 5.5 hr
# [epoch=2] batch 225 of 1125 - 20.00% done - 1:04:27.632144 ellapsed, est. total time: 5.4 hr
# [epoch=2] batch 230 of 1125 - 20.44% done - 1:04:35.886551 ellapsed, est. total time: 5.3 hr
# [epoch=2] batch 235 of 1125 - 20.89% done - 1:04:45.686640 ellapsed, est. total time: 5.2 hr
# [epoch=2] batch 240 of 1125 - 21.33% done - 1:04:56.667625 ellapsed, est. total time: 5.1 hr
# [epoch=2] batch 245 of 1125 - 21.78% done - 1:05:06.626365 ellapsed, est. total time: 5.0 hr
# [epoch=2] batch 250 of 1125 - 22.22% done - 1:05:15.701220 ellapsed, est. total time: 4.9 hr
# [epoch=2] batch 255 of 1125 - 22.67% done - 1:05:23.236355 ellapsed, est. total time: 4.8 hr
# [epoch=2] batch 260 of 1125 - 23.11% done - 1:05:33.255760 ellapsed, est. total time: 4.7 hr
# [epoch=2] batch 265 of 1125 - 23.56% done - 1:05:41.203997 ellapsed, est. total time: 4.6 hr
# [epoch=2] batch 270 of 1125 - 24.00% done - 1:05:49.939427 ellapsed, est. total time: 4.6 hr
# [epoch=2] batch 275 of 1125 - 24.44% done - 1:05:59.989270 ellapsed, est. total time: 4.5 hr
# [epoch=2] batch 280 of 1125 - 24.89% done - 1:06:09.484403 ellapsed, est. total time: 4.4 hr
# [epoch=2] batch 285 of 1125 - 25.33% done - 1:06:18.287387 ellapsed, est. total time: 4.4 hr
# [epoch=2] batch 290 of 1125 - 25.78% done - 1:06:25.792331 ellapsed, est. total time: 4.3 hr
# [epoch=2] batch 295 of 1125 - 26.22% done - 1:06:34.078957 ellapsed, est. total time: 4.2 hr
# [epoch=2] batch 300 of 1125 - 26.67% done - 1:06:42.059084 ellapsed, est. total time: 4.2 hr
# [epoch=2] batch 305 of 1125 - 27.11% done - 1:06:50.691106 ellapsed, est. total time: 4.1 hr
# [epoch=2] batch 310 of 1125 - 27.56% done - 1:06:58.311861 ellapsed, est. total time: 4.1 hr
# [epoch=2] batch 315 of 1125 - 28.00% done - 1:07:06.788622 ellapsed, est. total time: 4.0 hr
# [epoch=2] batch 320 of 1125 - 28.44% done - 1:07:14.682507 ellapsed, est. total time: 3.9 hr
# [epoch=2] batch 325 of 1125 - 28.89% done - 1:07:22.218517 ellapsed, est. total time: 3.9 hr
# ...
# [epoch=7] batch 270 of 1125 - 24.00% done - 3:26:58.705646 ellapsed, est. total time: 14.4 hr
# [epoch=7] batch 275 of 1125 - 24.44% done - 3:27:05.820238 ellapsed, est. total time: 14.1 hr
# [epoch=7] batch 280 of 1125 - 24.89% done - 3:27:13.284058 ellapsed, est. total time: 13.9 hr
# [epoch=7] batch 285 of 1125 - 25.33% done - 3:27:21.442053 ellapsed, est. total time: 13.6 hr
# [epoch=7] batch 290 of 1125 - 25.78% done - 3:27:28.795637 ellapsed, est. total time: 13.4 hr
# [epoch=7] batch 295 of 1125 - 26.22% done - 3:27:35.420957 ellapsed, est. total time: 13.2 hr
# [epoch=7] batch 300 of 1125 - 26.67% done - 3:27:43.053218 ellapsed, est. total time: 13.0 hr
# [epoch=7] batch 305 of 1125 - 27.11% done - 3:27:50.762020 ellapsed, est. total time: 12.8 hr
# [epoch=7] batch 310 of 1125 - 27.56% done - 3:27:58.058246 ellapsed, est. total time: 12.6 hr
# [epoch=7] batch 315 of 1125 - 28.00% done - 3:28:05.042672 ellapsed, est. total time: 12.4 hr
# [epoch=7] batch 320 of 1125 - 28.44% done - 3:28:12.380155 ellapsed, est. total time: 12.2 hr
# [epoch=7] batch 325 of 1125 - 28.89% done - 3:28:19.349102 ellapsed, est. total time: 12.0 hr
# [epoch=7] batch 330 of 1125 - 29.33% done - 3:28:27.501819 ellapsed, est. total time: 11.8 hr
# [epoch=7] batch 335 of 1125 - 29.78% done - 3:28:34.418606 ellapsed, est. total time: 11.7 hr
# [epoch=7] batch 340 of 1125 - 30.22% done - 3:28:42.041325 ellapsed, est. total time: 11.5 hr
# [epoch=7] batch 345 of 1125 - 30.67% done - 3:28:50.069959 ellapsed, est. total time: 11.3 hr
# [epoch=7] batch 350 of 1125 - 31.11% done - 3:28:57.750978 ellapsed, est. total time: 11.2 hr
# [epoch=7] batch 355 of 1125 - 31.56% done - 3:29:04.501030 ellapsed, est. total time: 11.0 hr
# [epoch=7] batch 360 of 1125 - 32.00% done - 3:29:11.713028 ellapsed, est. total time: 10.9 hr
# [epoch=7] batch 365 of 1125 - 32.44% done - 3:29:19.292228 ellapsed, est. total time: 10.8 hr
# [epoch=7] batch 370 of 1125 - 32.89% done - 3:29:26.828671 ellapsed, est. total time: 10.6 hr
# [epoch=7] batch 375 of 1125 - 33.33% done - 3:29:34.276905 ellapsed, est. total time: 10.5 hr
# [epoch=7] batch 380 of 1125 - 33.78% done - 3:29:41.852931 ellapsed, est. total time: 10.3 hr
# [epoch=7] batch 385 of 1125 - 34.22% done - 3:29:48.510733 ellapsed, est. total time: 10.2 hr
# [epoch=7] batch 390 of 1125 - 34.67% done - 3:29:56.647128 ellapsed, est. total time: 10.1 hr
# [epoch=7] batch 395 of 1125 - 35.11% done - 3:30:04.306435 ellapsed, est. total time: 10.0 hr
# [epoch=7] batch 400 of 1125 - 35.56% done - 3:30:11.970211 ellapsed, est. total time: 9.9 hr
# [epoch=7] batch 405 of 1125 - 36.00% done - 3:30:19.069081 ellapsed, est. total time: 9.7 hr
# [epoch=7] batch 410 of 1125 - 36.44% done - 3:30:26.083297 ellapsed, est. total time: 9.6 hr
# [epoch=7] batch 415 of 1125 - 36.89% done - 3:30:32.688588 ellapsed, est. total time: 9.5 hr
# [epoch=7] batch 420 of 1125 - 37.33% done - 3:30:40.339057 ellapsed, est. total time: 9.4 hr
# [epoch=7] batch 425 of 1125 - 37.78% done - 3:30:47.276561 ellapsed, est. total time: 9.3 hr
# [epoch=7] batch 430 of 1125 - 38.22% done - 3:30:55.171151 ellapsed, est. total time: 9.2 hr
# [epoch=7] batch 435 of 1125 - 38.67% done - 3:31:03.116024 ellapsed, est. total time: 9.1 hr
# [epoch=7] batch 440 of 1125 - 39.11% done - 3:31:09.724867 ellapsed, est. total time: 9.0 hr
# [epoch=7] batch 445 of 1125 - 39.56% done - 3:31:17.133789 ellapsed, est. total time: 8.9 hr
# [epoch=7] batch 450 of 1125 - 40.00% done - 3:31:24.944987 ellapsed, est. total time: 8.8 hr
# [epoch=7] batch 455 of 1125 - 40.44% done - 3:31:32.386794 ellapsed, est. total time: 8.7 hr
# [epoch=7] batch 460 of 1125 - 40.89% done - 3:31:39.957736 ellapsed, est. total time: 8.6 hr
# [epoch=7] batch 465 of 1125 - 41.33% done - 3:31:47.408288 ellapsed, est. total time: 8.5 hr
# [epoch=7] batch 470 of 1125 - 41.78% done - 3:31:55.421724 ellapsed, est. total time: 8.5 hr
# [epoch=7] batch 475 of 1125 - 42.22% done - 3:32:03.151411 ellapsed, est. total time: 8.4 hr
# [epoch=7] batch 480 of 1125 - 42.67% done - 3:32:10.801027 ellapsed, est. total time: 8.3 hr
# [epoch=7] batch 485 of 1125 - 43.11% done - 3:32:18.411063 ellapsed, est. total time: 8.2 hr
# [epoch=7] batch 490 of 1125 - 43.56% done - 3:32:24.949785 ellapsed, est. total time: 8.1 hr
# [epoch=7] batch 495 of 1125 - 44.00% done - 3:32:31.889659 ellapsed, est. total time: 8.1 hr
# [epoch=7] batch 500 of 1125 - 44.44% done - 3:32:38.521688 ellapsed, est. total time: 8.0 hr
# [epoch=7] batch 505 of 1125 - 44.89% done - 3:32:45.205044 ellapsed, est. total time: 7.9 hr
# [epoch=7] batch 510 of 1125 - 45.33% done - 3:32:53.132821 ellapsed, est. total time: 7.8 hr
# [epoch=7] batch 515 of 1125 - 45.78% done - 3:33:01.444315 ellapsed, est. total time: 7.8 hr
# [epoch=7] batch 520 of 1125 - 46.22% done - 3:33:09.077902 ellapsed, est. total time: 7.7 hr
# [epoch=7] batch 525 of 1125 - 46.67% done - 3:33:16.456177 ellapsed, est. total time: 7.6 hr
# [epoch=7] batch 530 of 1125 - 47.11% done - 3:33:23.936713 ellapsed, est. total time: 7.5 hr
# [epoch=7] batch 535 of 1125 - 47.56% done - 3:33:31.384747 ellapsed, est. total time: 7.5 hr
# [epoch=7] batch 540 of 1125 - 48.00% done - 3:33:38.847498 ellapsed, est. total time: 7.4 hr
# [epoch=7] batch 545 of 1125 - 48.44% done - 3:33:46.714262 ellapsed, est. total time: 7.4 hr
# [epoch=7] batch 550 of 1125 - 48.89% done - 3:33:54.044332 ellapsed, est. total time: 7.3 hr
# [epoch=7] batch 555 of 1125 - 49.33% done - 3:34:01.078591 ellapsed, est. total time: 7.2 hr
# [epoch=7] batch 560 of 1125 - 49.78% done - 3:34:08.970088 ellapsed, est. total time: 7.2 hr
# [epoch=7] batch 565 of 1125 - 50.22% done - 3:34:16.257823 ellapsed, est. total time: 7.1 hr
# [epoch=7] batch 570 of 1125 - 50.67% done - 3:34:23.933296 ellapsed, est. total time: 7.1 hr
# [epoch=7] batch 575 of 1125 - 51.11% done - 3:34:31.330689 ellapsed, est. total time: 7.0 hr
# [epoch=7] batch 580 of 1125 - 51.56% done - 3:34:38.417908 ellapsed, est. total time: 6.9 hr
# [epoch=7] batch 585 of 1125 - 52.00% done - 3:34:45.583387 ellapsed, est. total time: 6.9 hr
# [epoch=7] batch 590 of 1125 - 52.44% done - 3:34:51.849616 ellapsed, est. total time: 6.8 hr
# [epoch=7] batch 595 of 1125 - 52.89% done - 3:34:59.175329 ellapsed, est. total time: 6.8 hr
# [epoch=7] batch 600 of 1125 - 53.33% done - 3:35:06.402150 ellapsed, est. total time: 6.7 hr
# [epoch=7] batch 605 of 1125 - 53.78% done - 3:35:14.105177 ellapsed, est. total time: 6.7 hr
# [epoch=7] batch 610 of 1125 - 54.22% done - 3:35:21.227016 ellapsed, est. total time: 6.6 hr
# [epoch=7] batch 615 of 1125 - 54.67% done - 3:35:28.834655 ellapsed, est. total time: 6.6 hr
# [epoch=7] batch 620 of 1125 - 55.11% done - 3:35:36.204887 ellapsed, est. total time: 6.5 hr
# [epoch=7] batch 625 of 1125 - 55.56% done - 3:35:43.089001 ellapsed, est. total time: 6.5 hr
# [epoch=7] batch 630 of 1125 - 56.00% done - 3:35:49.224559 ellapsed, est. total time: 6.4 hr
# [epoch=7] batch 635 of 1125 - 56.44% done - 3:35:56.538267 ellapsed, est. total time: 6.4 hr
# [epoch=7] batch 640 of 1125 - 56.89% done - 3:36:03.875449 ellapsed, est. total time: 6.3 hr
# [epoch=7] batch 645 of 1125 - 57.33% done - 3:36:10.484308 ellapsed, est. total time: 6.3 hr
# [epoch=7] batch 650 of 1125 - 57.78% done - 3:36:17.008387 ellapsed, est. total time: 6.2 hr
# [epoch=7] batch 655 of 1125 - 58.22% done - 3:36:23.941197 ellapsed, est. total time: 6.2 hr
# [epoch=7] batch 660 of 1125 - 58.67% done - 3:36:31.390650 ellapsed, est. total time: 6.2 hr
# [epoch=7] batch 665 of 1125 - 59.11% done - 3:36:40.451283 ellapsed, est. total time: 6.1 hr
# [epoch=7] batch 670 of 1125 - 59.56% done - 3:36:47.170559 ellapsed, est. total time: 6.1 hr
# [epoch=7] batch 675 of 1125 - 60.00% done - 3:36:54.518984 ellapsed, est. total time: 6.0 hr
# [epoch=7] batch 680 of 1125 - 60.44% done - 3:37:01.463652 ellapsed, est. total time: 6.0 hr
# [epoch=7] batch 685 of 1125 - 60.89% done - 3:37:08.294095 ellapsed, est. total time: 5.9 hr
# [epoch=7] batch 690 of 1125 - 61.33% done - 3:37:16.518022 ellapsed, est. total time: 5.9 hr
# [epoch=7] batch 695 of 1125 - 61.78% done - 3:37:24.552483 ellapsed, est. total time: 5.9 hr
# [epoch=7] batch 700 of 1125 - 62.22% done - 3:37:31.540883 ellapsed, est. total time: 5.8 hr
# [epoch=7] batch 705 of 1125 - 62.67% done - 3:37:38.162983 ellapsed, est. total time: 5.8 hr
# [epoch=7] batch 710 of 1125 - 63.11% done - 3:37:45.109210 ellapsed, est. total time: 5.8 hr
# [epoch=7] batch 715 of 1125 - 63.56% done - 3:37:53.085949 ellapsed, est. total time: 5.7 hr
# [epoch=7] batch 720 of 1125 - 64.00% done - 3:38:00.159393 ellapsed, est. total time: 5.7 hr
# [epoch=7] batch 725 of 1125 - 64.44% done - 3:38:07.708848 ellapsed, est. total time: 5.6 hr
# [epoch=7] batch 730 of 1125 - 64.89% done - 3:38:14.880440 ellapsed, est. total time: 5.6 hr
# [epoch=7] batch 735 of 1125 - 65.33% done - 3:38:22.131368 ellapsed, est. total time: 5.6 hr
# [epoch=7] batch 740 of 1125 - 65.78% done - 3:38:30.176152 ellapsed, est. total time: 5.5 hr
# [epoch=7] batch 745 of 1125 - 66.22% done - 3:38:38.139552 ellapsed, est. total time: 5.5 hr
# [epoch=7] batch 750 of 1125 - 66.67% done - 3:38:45.832245 ellapsed, est. total time: 5.5 hr
# [epoch=7] batch 755 of 1125 - 67.11% done - 3:38:52.212432 ellapsed, est. total time: 5.4 hr
# [epoch=7] batch 760 of 1125 - 67.56% done - 3:38:59.949464 ellapsed, est. total time: 5.4 hr
# [epoch=7] batch 765 of 1125 - 68.00% done - 3:39:07.475302 ellapsed, est. total time: 5.4 hr
# [epoch=7] batch 770 of 1125 - 68.44% done - 3:39:15.317040 ellapsed, est. total time: 5.3 hr
# [epoch=7] batch 775 of 1125 - 68.89% done - 3:39:22.467085 ellapsed, est. total time: 5.3 hr
# [epoch=7] batch 780 of 1125 - 69.33% done - 3:39:29.887164 ellapsed, est. total time: 5.3 hr
# [epoch=7] batch 785 of 1125 - 69.78% done - 3:39:37.560690 ellapsed, est. total time: 5.2 hr
# [epoch=7] batch 790 of 1125 - 70.22% done - 3:39:44.450482 ellapsed, est. total time: 5.2 hr
# [epoch=7] batch 795 of 1125 - 70.67% done - 3:39:52.315222 ellapsed, est. total time: 5.2 hr
# [epoch=7] batch 800 of 1125 - 71.11% done - 3:40:00.293142 ellapsed, est. total time: 5.2 hr
# [epoch=7] batch 805 of 1125 - 71.56% done - 3:40:08.302879 ellapsed, est. total time: 5.1 hr
# [epoch=7] batch 810 of 1125 - 72.00% done - 3:40:15.453263 ellapsed, est. total time: 5.1 hr
# [epoch=7] batch 815 of 1125 - 72.44% done - 3:40:22.440493 ellapsed, est. total time: 5.1 hr
# [epoch=7] batch 820 of 1125 - 72.89% done - 3:40:29.457433 ellapsed, est. total time: 5.0 hr
# [epoch=7] batch 825 of 1125 - 73.33% done - 3:40:37.465424 ellapsed, est. total time: 5.0 hr
# [epoch=7] batch 830 of 1125 - 73.78% done - 3:40:44.890508 ellapsed, est. total time: 5.0 hr
# [epoch=7] batch 835 of 1125 - 74.22% done - 3:40:52.703737 ellapsed, est. total time: 5.0 hr
# [epoch=7] batch 840 of 1125 - 74.67% done - 3:41:00.527681 ellapsed, est. total time: 4.9 hr
# [epoch=7] batch 845 of 1125 - 75.11% done - 3:41:07.233240 ellapsed, est. total time: 4.9 hr
# [epoch=7] batch 850 of 1125 - 75.56% done - 3:41:15.023752 ellapsed, est. total time: 4.9 hr
# [epoch=7] batch 855 of 1125 - 76.00% done - 3:41:22.037700 ellapsed, est. total time: 4.9 hr
# [epoch=7] batch 860 of 1125 - 76.44% done - 3:41:29.782979 ellapsed, est. total time: 4.8 hr
# [epoch=7] batch 865 of 1125 - 76.89% done - 3:41:36.955869 ellapsed, est. total time: 4.8 hr
# [epoch=7] batch 870 of 1125 - 77.33% done - 3:41:44.837849 ellapsed, est. total time: 4.8 hr
# [epoch=7] batch 875 of 1125 - 77.78% done - 3:41:51.697653 ellapsed, est. total time: 4.8 hr
# [epoch=7] batch 880 of 1125 - 78.22% done - 3:41:58.999216 ellapsed, est. total time: 4.7 hr
# [epoch=7] batch 885 of 1125 - 78.67% done - 3:42:06.489351 ellapsed, est. total time: 4.7 hr
# [epoch=7] batch 890 of 1125 - 79.11% done - 3:42:14.147592 ellapsed, est. total time: 4.7 hr
# [epoch=7] batch 895 of 1125 - 79.56% done - 3:42:22.081935 ellapsed, est. total time: 4.7 hr
# [epoch=7] batch 900 of 1125 - 80.00% done - 3:42:29.342510 ellapsed, est. total time: 4.6 hr
# [epoch=7] batch 905 of 1125 - 80.44% done - 3:42:37.041427 ellapsed, est. total time: 4.6 hr
# [epoch=7] batch 910 of 1125 - 80.89% done - 3:42:43.865677 ellapsed, est. total time: 4.6 hr
# [epoch=7] batch 915 of 1125 - 81.33% done - 3:42:50.840726 ellapsed, est. total time: 4.6 hr
# [epoch=7] batch 920 of 1125 - 81.78% done - 3:42:59.073619 ellapsed, est. total time: 4.5 hr
# [epoch=7] batch 925 of 1125 - 82.22% done - 3:43:05.879734 ellapsed, est. total time: 4.5 hr
# [epoch=7] batch 930 of 1125 - 82.67% done - 3:43:12.961865 ellapsed, est. total time: 4.5 hr
# [epoch=7] batch 935 of 1125 - 83.11% done - 3:43:20.238726 ellapsed, est. total time: 4.5 hr
# [epoch=7] batch 940 of 1125 - 83.56% done - 3:43:27.653479 ellapsed, est. total time: 4.5 hr
# [epoch=7] batch 945 of 1125 - 84.00% done - 3:43:35.531091 ellapsed, est. total time: 4.4 hr
# [epoch=7] batch 950 of 1125 - 84.44% done - 3:43:42.366157 ellapsed, est. total time: 4.4 hr
# [epoch=7] batch 955 of 1125 - 84.89% done - 3:43:50.012099 ellapsed, est. total time: 4.4 hr
# [epoch=7] batch 960 of 1125 - 85.33% done - 3:43:57.699540 ellapsed, est. total time: 4.4 hr
# [epoch=7] batch 965 of 1125 - 85.78% done - 3:44:05.030903 ellapsed, est. total time: 4.4 hr
# [epoch=7] batch 970 of 1125 - 86.22% done - 3:44:12.860892 ellapsed, est. total time: 4.3 hr
# [epoch=7] batch 975 of 1125 - 86.67% done - 3:44:19.733399 ellapsed, est. total time: 4.3 hr
# [epoch=7] batch 980 of 1125 - 87.11% done - 3:44:26.549992 ellapsed, est. total time: 4.3 hr
# [epoch=7] batch 985 of 1125 - 87.56% done - 3:44:33.259984 ellapsed, est. total time: 4.3 hr
# [epoch=7] batch 990 of 1125 - 88.00% done - 3:44:40.530042 ellapsed, est. total time: 4.3 hr
# [epoch=7] batch 995 of 1125 - 88.44% done - 3:44:47.268906 ellapsed, est. total time: 4.2 hr
# [epoch=7] batch 1000 of 1125 - 88.89% done - 3:44:54.249987 ellapsed, est. total time: 4.2 hr
# [epoch=7] batch 1005 of 1125 - 89.33% done - 3:45:01.571052 ellapsed, est. total time: 4.2 hr
# [epoch=7] batch 1010 of 1125 - 89.78% done - 3:45:09.523172 ellapsed, est. total time: 4.2 hr
# [epoch=7] batch 1015 of 1125 - 90.22% done - 3:45:16.983214 ellapsed, est. total time: 4.2 hr
# [epoch=7] batch 1020 of 1125 - 90.67% done - 3:45:23.485732 ellapsed, est. total time: 4.1 hr
# [epoch=7] batch 1025 of 1125 - 91.11% done - 3:45:30.911586 ellapsed, est. total time: 4.1 hr
# [epoch=7] batch 1030 of 1125 - 91.56% done - 3:45:37.869888 ellapsed, est. total time: 4.1 hr
# [epoch=7] batch 1035 of 1125 - 92.00% done - 3:45:44.995974 ellapsed, est. total time: 4.1 hr
# [epoch=7] batch 1040 of 1125 - 92.44% done - 3:45:52.621359 ellapsed, est. total time: 4.1 hr
# [epoch=7] batch 1045 of 1125 - 92.89% done - 3:45:59.668818 ellapsed, est. total time: 4.1 hr
# [epoch=7] batch 1050 of 1125 - 93.33% done - 3:46:06.611905 ellapsed, est. total time: 4.0 hr
# [epoch=7] batch 1055 of 1125 - 93.78% done - 3:46:13.088906 ellapsed, est. total time: 4.0 hr
# [epoch=7] batch 1060 of 1125 - 94.22% done - 3:46:20.348781 ellapsed, est. total time: 4.0 hr
# [epoch=7] batch 1065 of 1125 - 94.67% done - 3:46:28.221295 ellapsed, est. total time: 4.0 hr
# [epoch=7] batch 1070 of 1125 - 95.11% done - 3:46:35.594267 ellapsed, est. total time: 4.0 hr
# [epoch=7] batch 1075 of 1125 - 95.56% done - 3:46:42.651103 ellapsed, est. total time: 4.0 hr
# [epoch=7] batch 1080 of 1125 - 96.00% done - 3:46:49.922701 ellapsed, est. total time: 3.9 hr
# [epoch=7] batch 1085 of 1125 - 96.44% done - 3:46:57.921129 ellapsed, est. total time: 3.9 hr
# [epoch=7] batch 1090 of 1125 - 96.89% done - 3:47:05.096678 ellapsed, est. total time: 3.9 hr
# [epoch=7] batch 1095 of 1125 - 97.33% done - 3:47:12.709004 ellapsed, est. total time: 3.9 hr
# [epoch=7] batch 1100 of 1125 - 97.78% done - 3:47:19.763487 ellapsed, est. total time: 3.9 hr
# [epoch=7] batch 1105 of 1125 - 98.22% done - 3:47:26.861780 ellapsed, est. total time: 3.9 hr
# [epoch=7] batch 1110 of 1125 - 98.67% done - 3:47:34.244569 ellapsed, est. total time: 3.8 hr
# [epoch=7] batch 1115 of 1125 - 99.11% done - 3:47:41.570779 ellapsed, est. total time: 3.8 hr
# [epoch=7] batch 1120 of 1125 - 99.56% done - 3:47:49.522334 ellapsed, est. total time: 3.8 hr

# %%
model.eval()
train_acc = calculate_accuracy(model, tokenizer, train_loader)
print(f'Training accuracy: {train_acc * 100:.2f}%')
# Out:
# Training accuracy: 98.31%

# %% [markdown]
# ### Evaluate

# %%
test_acc = calculate_accuracy(model, tokenizer, test_loader)
print(f'Test accuracy: {test_acc * 100:.2f}%')
# Out:
# Test accuracy: 93.90%

# %%
prompt = build_prompt("I'm so happy to be able to finetune an LLM!")
generated_text = generate_text(model, tokenizer, prompt)
generated_text
# Out:
# 'joy'
